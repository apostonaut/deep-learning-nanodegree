# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %% [markdown]
# What are all possible labels?
# -airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck
#
# What is the range of values for the image data?
#
# Are the labels in order or random?
# -the labels in order. Each label corresponds to the image with the same index

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 6
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 6:
# Image - Min Value: 0 Max Value: 235
# Image - Shape: (32, 32, 3)
# Label - Label Id: 4 Name: deer

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # x/x.max() will yield a result between 0 and 1 for every pixel
    x_array = np.array(x)
    x_array = x_array/x_array.max()
    return x_array

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %% [markdown]
# Nice job implementing the one_hot_encode function, good usage of scikit-learn's LabelBinarizer.
#
# Suggestion: I would move the declaration and fit of binarizer to outside the function. This ensures that the mapping is stored globally and the same for each dataset (although it won't affect the performance of this project).

# %%
from sklearn.preprocessing import LabelBinarizer
binarizer = None

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    #allows binarized label array to be saved outside of function
    global binarizer
    
    #initialize LabelBinarizer
    binarizer = LabelBinarizer() 
    binarizer.fit(x)
    binarizer.classes_ = np.array(list(range(10)))
    output = binarizer.transform(x)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

#Suggestion: you can also use [None + *image_shape].
def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    
    # [None] + list(image_shape)) ==> results in [None] + [32, 32, 3] = [None, 32, 32, 3]
    output = tf.placeholder(tf.float32, shape = ([None] + list(image_shape)), name = 'x')
    return output
    

def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    output = tf.placeholder(tf.float32, shape = ([None, n_classes] ), name='y')
    return output

def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    output = tf.placeholder(tf.float32, name='keep_prob')
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
import random
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor 
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    print("x_tensor", x_tensor)
    print("conv_num_outputs", conv_num_outputs)
    print("conv_ksize", conv_ksize)
    print("conv_strides", conv_strides)
    print("pool_ksize", pool_ksize)
    print("pool_strides", pool_strides)
    
    
    #for this function, our input image is is x_tensor
    # input = tf.placeholder(tf.float32, shape=[None, image_height, image_width, color_channels]
    
    #BEGINNING OF CONVOLUTION LAYER
    
    #create weights
    input_depth = x_tensor.get_shape().as_list()[-1]
    
    # outputs a "Dimension" object, not an int, which is why the .as_list() method needs to be added
    # >>> type(x_tensor.get_shape()[-1])
    # <class 'tensorflow.python.framework.tensor_shape.Dimension'>
    
    #weight = tf.Variable(tf.truncated_normal([filter_size_height,filter_size_width, color_channels, k_output]))
    weights = tf.Variable(tf.truncated_normal((conv_ksize[0],conv_ksize[1],input_depth,conv_num_outputs),stddev=0.05))
    
    #assign bias
    biases = tf.Variable(tf.zeros(conv_num_outputs))

    # Apply a convolution to x_tensor using weight and conv_strides. tf.nn.conv2D() parameters below for reference
    # tf.nn.conv2d(input, filter, strides, padding, use_cudnn_on_gpu=None, data_format=None, name=None)

    conv_layer = tf.nn.conv2d(x_tensor, weights, 
                strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, biases)
    
    # Non-linear activation function for conv_layer
    conv_layer = tf.nn.relu(conv_layer)
    
    
    #END OF CONVOLUTION LAYER
    
    #BEGINNING OF POOLING LAYER: Apply Max Pooling using pool_ksize and pool_strides.
    
    # output shape of pooling layer should be [None, 4, 4, 10]
    # tf.nn.max_pool(value, ksize, strides, padding, data_format='NHWC', name=None)
    pool_ksize = [1, pool_ksize[0], pool_ksize[1], 1]
    pool_strides = [1, pool_strides[0], pool_strides[1], 1]
    
    maxpool_layer = tf.nn.max_pool(value=conv_layer, ksize=pool_ksize, strides=pool_strides, padding='SAME')
    #END OF POOLING LAYER
    
    return maxpool_layer

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %% [markdown]
# https://www.tensorflow.org/api_docs/python/tf/contrib/layers/flatten

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    
    #tf.reshape(tensor, shape, name=None)
    '''If one component of shape is the special value -1, the size of that dimension is computed so that 
    the total size remains constant. In particular, a shape of [-1] flattens into 1-D. At most one component 
    of shape can be -1.'''
    
    # FULL IMPLEMENTATION: is the use of new_dimensions correct???
    print(x_tensor.get_shape())
    x_tensor_shape = x_tensor.get_shape().as_list()
    new_dimensions = x_tensor_shape[1]*x_tensor_shape[2]*x_tensor_shape[3]
    flattened_tensor = tf.reshape(x_tensor, [-1, new_dimensions])
    
    return flattened_tensor
    
    # SHORTCUT
    #tf.contrib.layers.flatten(*args, **kwargs)
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # input x_tensor is already flattened, so don't need to reshape
    #weights and biases
    weights = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs], stddev=0.05))
    biases = tf.Variable(tf.zeros(num_outputs))
    
    #apply weights and biases
    fully_connected = tf.add(tf.matmul(x_tensor, weights), biases)
    
    #relu activation
    fully_connected = tf.nn.relu(fully_connected)
    
    return fully_connected
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply an output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    #initialize weights and biases
    weights = tf.Variable(tf.random_normal([x_tensor.get_shape().as_list()[1], num_outputs], stddev=0.05))
    biases = tf.Variable(tf.zeros(num_outputs))
    
    #create output layer
    #out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    output_layer = tf.add(tf.matmul(x_tensor, weights), biases)
    return output_layer

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %% [markdown]
# REVIEW
#
# Great work, you've correctly implemented the conv_net function that outputs the logits and uses a dropout.
#
# Suggestion: for convolutional networks I would also use multiply convolutional and fully connected layers. However, for the multiple convolutional layers I would advise you to use increasing depth (for example, double the number of filters each time: 32, 64, 128). Also, I would suggest to use small filters (for example a maximum of 3x3) and small strides (1x1). For the fully connected layers I would use decreasing number of hidden units (for example, 512, 256, and 128).
#
# For more background information on building a convolutional architecture, have a look at this link.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that holds dropout keep probability.
    : return: Tensor that represents logits
    """
    #initialize variables:
    ''' 
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    '''
    #conv_num_outputs = 50
    conv_ksize = (3,3)
    conv_strides = (2,2)
    pool_ksize = (4,4)
    pool_strides = (2,2)
    num_outputs = 10
    
    # Apply 1, 2, or 3 Convolution and Max Pool layers
    # Play around with different number of outputs, kernel size and stride
    conv_max1 = conv2d_maxpool(x, 50, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_max2 = conv2d_maxpool(conv_max1, 50, conv_ksize, conv_strides, pool_ksize, pool_strides)
    #conv_max3 = conv2d_maxpool(conv_max2, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)

    # Apply a Flatten Layer
    flatten_layer = flatten(conv_max2)
    
    # Apply 1, 2, or 3 Fully Connected Layers
    # Play around with different number of outputs
    fully_conn_layer1 = fully_conn(flatten_layer, 50)
    fully_conn_layer1 = tf.nn.dropout(fully_conn_layer1, keep_prob)
    
    #fully_conn_layer2 = fully_conn(fully_conn_layer1, num_outputs)
    #fully_conn_layer2 = tf.nn.dropout(fully_conn_layer2, keep_prob)
    #fully_conn_layer3 = fully_conn(fully_conn_layer2, num_outputs)
    
    # Apply an Output Layer
    # Set this to the number of classes
    output_layer = output(fully_conn_layer1, 10)
    
    # TODO: return output
    return output_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# x_tensor Tensor("x:0", shape=(?, 32, 32, 3), dtype=float32)
# conv_num_outputs 50
# conv_ksize (3, 3)
# conv_strides (2, 2)
# pool_ksize (4, 4)
# pool_strides (2, 2)
# x_tensor Tensor("MaxPool:0", shape=(?, 8, 8, 50), dtype=float32)
# conv_num_outputs 50
# conv_ksize (3, 3)
# conv_strides (2, 2)
# pool_ksize (4, 4)
# pool_strides (2, 2)
# (?, 2, 2, 50)
# x_tensor Tensor("Placeholder:0", shape=(?, 32, 32, 3), dtype=float32)
# conv_num_outputs 50
# conv_ksize (3, 3)
# conv_strides (2, 2)
# pool_ksize (4, 4)
# pool_strides (2, 2)
# x_tensor Tensor("MaxPool_2:0", shape=(?, 8, 8, 50), dtype=float32)
# conv_num_outputs 50
# conv_ksize (3, 3)
# conv_strides (2, 2)
# pool_ksize (4, 4)
# pool_strides (2, 2)
# (?, 2, 2, 50)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict = {x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    loss = sess.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    print('loss', loss)
    validation_accuracy = sess.run(accuracy, feed_dict={x: valid_features, y:valid_labels, keep_prob: 1.0})
    print('validation accuracty', validation_accuracy)

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 38
#Suggestion: for the batch size higher is usually better. 
# Did you try increasing the batch size?
batch_size = 64
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss 2.04243
# validation accuracty 0.2728
# Epoch  2, CIFAR-10 Batch 1:  loss 1.98486
# validation accuracty 0.3102
# Epoch  3, CIFAR-10 Batch 1:  loss 1.96041
# validation accuracty 0.3326
# Epoch  4, CIFAR-10 Batch 1:  loss 1.88907
# validation accuracty 0.3758
# Epoch  5, CIFAR-10 Batch 1:  loss 1.81241
# validation accuracty 0.4076
# Epoch  6, CIFAR-10 Batch 1:  loss 1.7707
# validation accuracty 0.4054
# Epoch  7, CIFAR-10 Batch 1:  loss 1.70543
# validation accuracty 0.4298
# Epoch  8, CIFAR-10 Batch 1:  loss 1.70045
# validation accuracty 0.4318
# Epoch  9, CIFAR-10 Batch 1:  loss 1.63136
# validation accuracty 0.4532
# Epoch 10, CIFAR-10 Batch 1:  loss 1.58804
# validation accuracty 0.4522
# Epoch 11, CIFAR-10 Batch 1:  loss 1.55305
# validation accuracty 0.4676
# Epoch 12, CIFAR-10 Batch 1:  loss 1.53623
# validation accuracty 0.456
# Epoch 13, CIFAR-10 Batch 1:  loss 1.48222
# validation accuracty 0.4778
# Epoch 14, CIFAR-10 Batch 1:  loss 1.42286
# validation accuracty 0.4874
# Epoch 15, CIFAR-10 Batch 1:  loss 1.48499
# validation accuracty 0.4776
# Epoch 16, CIFAR-10 Batch 1:  loss 1.43842
# validation accuracty 0.5008
# Epoch 17, CIFAR-10 Batch 1:  loss 1.37083
# validation accuracty 0.4904
# Epoch 18, CIFAR-10 Batch 1:  loss 1.34719
# validation accuracty 0.5064
# Epoch 19, CIFAR-10 Batch 1:  loss 1.33461
# validation accuracty 0.5126
# Epoch 20, CIFAR-10 Batch 1:  loss 1.28688
# validation accuracty 0.5138
# Epoch 21, CIFAR-10 Batch 1:  loss 1.27178
# validation accuracty 0.5202
# Epoch 22, CIFAR-10 Batch 1:  loss 1.25058
# validation accuracty 0.5216
# Epoch 23, CIFAR-10 Batch 1:  loss 1.22085
# validation accuracty 0.528
# Epoch 24, CIFAR-10 Batch 1:  loss 1.20404
# validation accuracty 0.5296
# Epoch 25, CIFAR-10 Batch 1:  loss 1.16103
# validation accuracty 0.5304
# Epoch 26, CIFAR-10 Batch 1:  loss 1.19389
# validation accuracty 0.5334
# Epoch 27, CIFAR-10 Batch 1:  loss 1.15464
# validation accuracty 0.539
# Epoch 28, CIFAR-10 Batch 1:  loss 1.10806
# validation accuracty 0.5354
# Epoch 29, CIFAR-10 Batch 1:  loss 1.10195
# validation accuracty 0.5426
# Epoch 30, CIFAR-10 Batch 1:  loss 1.09215
# validation accuracty 0.5422
# Epoch 31, CIFAR-10 Batch 1:  loss 1.05138
# validation accuracty 0.546
# Epoch 32, CIFAR-10 Batch 1:  loss 1.10464
# validation accuracty 0.5274
# Epoch 33, CIFAR-10 Batch 1:  loss 1.02034
# validation accuracty 0.5442
# Epoch 34, CIFAR-10 Batch 1:  loss 1.00125
# validation accuracty 0.5484
# Epoch 35, CIFAR-10 Batch 1:  loss 1.01253
# validation accuracty 0.5476
# Epoch 36, CIFAR-10 Batch 1:  loss 1.03788
# validation accuracty 0.5486
# Epoch 37, CIFAR-10 Batch 1:  loss 0.970677
# validation accuracty 0.5578
# Epoch 38, CIFAR-10 Batch 1:  loss 0.974285
# validation accuracty 0.5564
# Epoch 39, CIFAR-10 Batch 1:  loss 0.936903
# validation accuracty 0.5504
# Epoch 40, CIFAR-10 Batch 1:  loss 0.959515
# validation accuracty 0.5616
# Epoch 41, CIFAR-10 Batch 1:  loss 0.934312
# validation accuracty 0.5434
# Epoch 42, CIFAR-10 Batch 1:  loss 0.96096
# validation accuracty 0.545
# Epoch 43, CIFAR-10 Batch 1:  loss 0.913674
# validation accuracty 0.5588
# Epoch 44, CIFAR-10 Batch 1:  loss 0.927676
# validation accuracty 0.5654
# Epoch 45, CIFAR-10 Batch 1:  loss 0.948568
# validation accuracty 0.5516
# Epoch 46, CIFAR-10 Batch 1:  loss 0.907677
# validation accuracty 0.5634
# Epoch 47, CIFAR-10 Batch 1:  loss 0.877082
# validation accuracty 0.5604
# Epoch 48, CIFAR-10 Batch 1:  loss 0.905361
# validation accuracty 0.5546
# Epoch 49, CIFAR-10 Batch 1:  loss 0.850736
# validation accuracty 0.5526
# Epoch 50, CIFAR-10 Batch 1:  loss 0.946372
# validation accuracty 0.5442

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss 2.08801
# validation accuracty 0.242
# Epoch  1, CIFAR-10 Batch 2:  loss 1.88427
# validation accuracty 0.2904
# Epoch  1, CIFAR-10 Batch 3:  loss 1.69352
# validation accuracty 0.3172
# Epoch  1, CIFAR-10 Batch 4:  loss 1.83984
# validation accuracty 0.3464
# Epoch  1, CIFAR-10 Batch 5:  loss 1.73654
# validation accuracty 0.34
# Epoch  2, CIFAR-10 Batch 1:  loss 1.95847
# validation accuracty 0.357
# Epoch  2, CIFAR-10 Batch 2:  loss 1.80468
# validation accuracty 0.3806
# Epoch  2, CIFAR-10 Batch 3:  loss 1.54844
# validation accuracty 0.381
# Epoch  2, CIFAR-10 Batch 4:  loss 1.7497
# validation accuracty 0.4038
# Epoch  2, CIFAR-10 Batch 5:  loss 1.71003
# validation accuracty 0.3986
# Epoch  3, CIFAR-10 Batch 1:  loss 1.77832
# validation accuracty 0.4178
# Epoch  3, CIFAR-10 Batch 2:  loss 1.61389
# validation accuracty 0.3968
# Epoch  3, CIFAR-10 Batch 3:  loss 1.44217
# validation accuracty 0.4328
# Epoch  3, CIFAR-10 Batch 4:  loss 1.6787
# validation accuracty 0.4428
# Epoch  3, CIFAR-10 Batch 5:  loss 1.63796
# validation accuracty 0.4286
# Epoch  4, CIFAR-10 Batch 1:  loss 1.67519
# validation accuracty 0.454
# Epoch  4, CIFAR-10 Batch 2:  loss 1.61899
# validation accuracty 0.46
# Epoch  4, CIFAR-10 Batch 3:  loss 1.32208
# validation accuracty 0.4558
# Epoch  4, CIFAR-10 Batch 4:  loss 1.61435
# validation accuracty 0.4584
# Epoch  4, CIFAR-10 Batch 5:  loss 1.53949
# validation accuracty 0.4512
# Epoch  5, CIFAR-10 Batch 1:  loss 1.58941
# validation accuracty 0.4836
# Epoch  5, CIFAR-10 Batch 2:  loss 1.56291
# validation accuracty 0.478
# Epoch  5, CIFAR-10 Batch 3:  loss 1.32968
# validation accuracty 0.4768
# Epoch  5, CIFAR-10 Batch 4:  loss 1.54549
# validation accuracty 0.4736
# Epoch  5, CIFAR-10 Batch 5:  loss 1.49001
# validation accuracty 0.4752
# Epoch  6, CIFAR-10 Batch 1:  loss 1.52163
# validation accuracty 0.4934
# Epoch  6, CIFAR-10 Batch 2:  loss 1.54647
# validation accuracty 0.4848
# Epoch  6, CIFAR-10 Batch 3:  loss 1.27498
# validation accuracty 0.4832
# Epoch  6, CIFAR-10 Batch 4:  loss 1.471
# validation accuracty 0.4906
# Epoch  6, CIFAR-10 Batch 5:  loss 1.46289
# validation accuracty 0.4842
# Epoch  7, CIFAR-10 Batch 1:  loss 1.44372
# validation accuracty 0.4966
# Epoch  7, CIFAR-10 Batch 2:  loss 1.49248
# validation accuracty 0.4908
# Epoch  7, CIFAR-10 Batch 3:  loss 1.20406
# validation accuracty 0.5066
# Epoch  7, CIFAR-10 Batch 4:  loss 1.44971
# validation accuracty 0.5018
# Epoch  7, CIFAR-10 Batch 5:  loss 1.39986
# validation accuracty 0.5052
# Epoch  8, CIFAR-10 Batch 1:  loss 1.41353
# validation accuracty 0.5062
# Epoch  8, CIFAR-10 Batch 2:  loss 1.44921
# validation accuracty 0.5138
# Epoch  8, CIFAR-10 Batch 3:  loss 1.17955
# validation accuracty 0.5106
# Epoch  8, CIFAR-10 Batch 4:  loss 1.39716
# validation accuracty 0.5186
# Epoch  8, CIFAR-10 Batch 5:  loss 1.37242
# validation accuracty 0.514
# Epoch  9, CIFAR-10 Batch 1:  loss 1.4216
# validation accuracty 0.5276
# Epoch  9, CIFAR-10 Batch 2:  loss 1.39773
# validation accuracty 0.5172
# Epoch  9, CIFAR-10 Batch 3:  loss 1.19973
# validation accuracty 0.5116
# Epoch  9, CIFAR-10 Batch 4:  loss 1.38548
# validation accuracty 0.5212
# Epoch  9, CIFAR-10 Batch 5:  loss 1.37976
# validation accuracty 0.512
# Epoch 10, CIFAR-10 Batch 1:  loss 1.33496
# validation accuracty 0.5316
# Epoch 10, CIFAR-10 Batch 2:  loss 1.34998
# validation accuracty 0.5286
# Epoch 10, CIFAR-10 Batch 3:  loss 1.14849
# validation accuracty 0.5248
# Epoch 10, CIFAR-10 Batch 4:  loss 1.34708
# validation accuracty 0.5322
# Epoch 10, CIFAR-10 Batch 5:  loss 1.35575
# validation accuracty 0.5184
# Epoch 11, CIFAR-10 Batch 1:  loss 1.29371
# validation accuracty 0.538
# Epoch 11, CIFAR-10 Batch 2:  loss 1.28064
# validation accuracty 0.5394
# Epoch 11, CIFAR-10 Batch 3:  loss 1.17185
# validation accuracty 0.5344
# Epoch 11, CIFAR-10 Batch 4:  loss 1.32623
# validation accuracty 0.5438
# Epoch 11, CIFAR-10 Batch 5:  loss 1.33915
# validation accuracty 0.538
# Epoch 12, CIFAR-10 Batch 1:  loss 1.24458
# validation accuracty 0.5488
# Epoch 12, CIFAR-10 Batch 2:  loss 1.28091
# validation accuracty 0.5452
# Epoch 12, CIFAR-10 Batch 3:  loss 1.15308
# validation accuracty 0.5308
# Epoch 12, CIFAR-10 Batch 4:  loss 1.29294
# validation accuracty 0.5522
# Epoch 12, CIFAR-10 Batch 5:  loss 1.25483
# validation accuracty 0.5508
# Epoch 13, CIFAR-10 Batch 1:  loss 1.25213
# validation accuracty 0.5564
# Epoch 13, CIFAR-10 Batch 2:  loss 1.3044
# validation accuracty 0.5532
# Epoch 13, CIFAR-10 Batch 3:  loss 1.10777
# validation accuracty 0.5444
# Epoch 13, CIFAR-10 Batch 4:  loss 1.25036
# validation accuracty 0.5514
# Epoch 13, CIFAR-10 Batch 5:  loss 1.28805
# validation accuracty 0.5492
# Epoch 14, CIFAR-10 Batch 1:  loss 1.1858
# validation accuracty 0.5594
# Epoch 14, CIFAR-10 Batch 2:  loss 1.32638
# validation accuracty 0.558
# Epoch 14, CIFAR-10 Batch 3:  loss 1.07373
# validation accuracty 0.5542
# Epoch 14, CIFAR-10 Batch 4:  loss 1.22852
# validation accuracty 0.5598
# Epoch 14, CIFAR-10 Batch 5:  loss 1.27582
# validation accuracty 0.5556
# Epoch 15, CIFAR-10 Batch 1:  loss 1.23289
# validation accuracty 0.5634
# Epoch 15, CIFAR-10 Batch 2:  loss 1.23696
# validation accuracty 0.553
# Epoch 15, CIFAR-10 Batch 3:  loss 1.03735
# validation accuracty 0.5622
# Epoch 15, CIFAR-10 Batch 4:  loss 1.19541
# validation accuracty 0.5706
# Epoch 15, CIFAR-10 Batch 5:  loss 1.2428
# validation accuracty 0.5682
# Epoch 16, CIFAR-10 Batch 1:  loss 1.14207
# validation accuracty 0.5748
# Epoch 16, CIFAR-10 Batch 2:  loss 1.19554
# validation accuracty 0.573
# Epoch 16, CIFAR-10 Batch 3:  loss 1.03021
# validation accuracty 0.5654
# Epoch 16, CIFAR-10 Batch 4:  loss 1.19875
# validation accuracty 0.5714
# Epoch 16, CIFAR-10 Batch 5:  loss 1.20518
# validation accuracty 0.5688
# Epoch 17, CIFAR-10 Batch 1:  loss 1.08598
# validation accuracty 0.5808
# Epoch 17, CIFAR-10 Batch 2:  loss 1.14654
# validation accuracty 0.5696
# Epoch 17, CIFAR-10 Batch 3:  loss 1.00809
# validation accuracty 0.5696
# Epoch 17, CIFAR-10 Batch 4:  loss 1.15828
# validation accuracty 0.579
# Epoch 17, CIFAR-10 Batch 5:  loss 1.14469
# validation accuracty 0.5726
# Epoch 18, CIFAR-10 Batch 1:  loss 1.13736
# validation accuracty 0.5678
# Epoch 18, CIFAR-10 Batch 2:  loss 1.13072
# validation accuracty 0.546
# Epoch 18, CIFAR-10 Batch 3:  loss 1.00794
# validation accuracty 0.5668
# Epoch 18, CIFAR-10 Batch 4:  loss 1.15267
# validation accuracty 0.5822
# Epoch 18, CIFAR-10 Batch 5:  loss 1.14849
# validation accuracty 0.5748
# Epoch 19, CIFAR-10 Batch 1:  loss 1.0894
# validation accuracty 0.5848
# Epoch 19, CIFAR-10 Batch 2:  loss 1.1582
# validation accuracty 0.583
# Epoch 19, CIFAR-10 Batch 3:  loss 1.03754
# validation accuracty 0.587
# Epoch 19, CIFAR-10 Batch 4:  loss 1.12406
# validation accuracty 0.5846
# Epoch 19, CIFAR-10 Batch 5:  loss 1.12527
# validation accuracty 0.5892
# Epoch 20, CIFAR-10 Batch 1:  loss 1.08422
# validation accuracty 0.5896
# Epoch 20, CIFAR-10 Batch 2:  loss 1.06646
# validation accuracty 0.5856
# Epoch 20, CIFAR-10 Batch 3:  loss 1.05287
# validation accuracty 0.566
# Epoch 20, CIFAR-10 Batch 4:  loss 1.12133
# validation accuracty 0.5884
# Epoch 20, CIFAR-10 Batch 5:  loss 1.09808
# validation accuracty 0.5854
# Epoch 21, CIFAR-10 Batch 1:  loss 1.12423
# validation accuracty 0.5778
# Epoch 21, CIFAR-10 Batch 2:  loss 1.06442
# validation accuracty 0.5846
# Epoch 21, CIFAR-10 Batch 3:  loss 1.01757
# validation accuracty 0.5762
# Epoch 21, CIFAR-10 Batch 4:  loss 1.07415
# validation accuracty 0.5916
# Epoch 21, CIFAR-10 Batch 5:  loss 1.11151
# validation accuracty 0.5836
# Epoch 22, CIFAR-10 Batch 1:  loss 1.09611
# validation accuracty 0.5872
# Epoch 22, CIFAR-10 Batch 2:  loss 1.04082
# validation accuracty 0.58
# Epoch 22, CIFAR-10 Batch 3:  loss 0.981902
# validation accuracty 0.5748
# Epoch 22, CIFAR-10 Batch 4:  loss 1.05962
# validation accuracty 0.5942
# Epoch 22, CIFAR-10 Batch 5:  loss 1.07058
# validation accuracty 0.576
# Epoch 23, CIFAR-10 Batch 1:  loss 1.06845
# validation accuracty 0.5948
# Epoch 23, CIFAR-10 Batch 2:  loss 1.06597
# validation accuracty 0.5928
# Epoch 23, CIFAR-10 Batch 3:  loss 1.02018
# validation accuracty 0.5836
# Epoch 23, CIFAR-10 Batch 4:  loss 1.08882
# validation accuracty 0.588
# Epoch 23, CIFAR-10 Batch 5:  loss 1.00552
# validation accuracty 0.5876
# Epoch 24, CIFAR-10 Batch 1:  loss 0.991389
# validation accuracty 0.5962
# Epoch 24, CIFAR-10 Batch 2:  loss 1.04211
# validation accuracty 0.5868
# Epoch 24, CIFAR-10 Batch 3:  loss 0.981166
# validation accuracty 0.5804
# Epoch 24, CIFAR-10 Batch 4:  loss 1.01219
# validation accuracty 0.5932
# Epoch 24, CIFAR-10 Batch 5:  loss 1.02601
# validation accuracty 0.5976
# Epoch 25, CIFAR-10 Batch 1:  loss 1.07325
# validation accuracty 0.5858
# Epoch 25, CIFAR-10 Batch 2:  loss 1.0101
# validation accuracty 0.5902
# Epoch 25, CIFAR-10 Batch 3:  loss 0.881877
# validation accuracty 0.587
# Epoch 25, CIFAR-10 Batch 4:  loss 1.02092
# validation accuracty 0.5952
# Epoch 25, CIFAR-10 Batch 5:  loss 1.01727
# validation accuracty 0.5902
# Epoch 26, CIFAR-10 Batch 1:  loss 1.03437
# validation accuracty 0.599
# Epoch 26, CIFAR-10 Batch 2:  loss 0.971206
# validation accuracty 0.5932
# Epoch 26, CIFAR-10 Batch 3:  loss 0.881391
# validation accuracty 0.6028
# Epoch 26, CIFAR-10 Batch 4:  loss 1.01306
# validation accuracty 0.595
# Epoch 26, CIFAR-10 Batch 5:  loss 0.971778
# validation accuracty 0.5988
# Epoch 27, CIFAR-10 Batch 1:  loss 0.97217
# validation accuracty 0.5986
# Epoch 27, CIFAR-10 Batch 2:  loss 0.966962
# validation accuracty 0.5996
# Epoch 27, CIFAR-10 Batch 3:  loss 0.890319
# validation accuracty 0.5968
# Epoch 27, CIFAR-10 Batch 4:  loss 1.00303
# validation accuracty 0.6016
# Epoch 27, CIFAR-10 Batch 5:  loss 0.914758
# validation accuracty 0.5788
# Epoch 28, CIFAR-10 Batch 1:  loss 0.981822
# validation accuracty 0.5974
# Epoch 28, CIFAR-10 Batch 2:  loss 0.966923
# validation accuracty 0.6028
# Epoch 28, CIFAR-10 Batch 3:  loss 0.858444
# validation accuracty 0.6028
# Epoch 28, CIFAR-10 Batch 4:  loss 0.941628
# validation accuracty 0.5998
# Epoch 28, CIFAR-10 Batch 5:  loss 0.976993
# validation accuracty 0.5938
# Epoch 29, CIFAR-10 Batch 1:  loss 0.975688
# validation accuracty 0.6064
# Epoch 29, CIFAR-10 Batch 2:  loss 0.944575
# validation accuracty 0.6
# Epoch 29, CIFAR-10 Batch 3:  loss 0.846991
# validation accuracty 0.6
# Epoch 29, CIFAR-10 Batch 4:  loss 0.994194
# validation accuracty 0.587
# Epoch 29, CIFAR-10 Batch 5:  loss 0.97113
# validation accuracty 0.6022
# Epoch 30, CIFAR-10 Batch 1:  loss 1.00987
# validation accuracty 0.608
# Epoch 30, CIFAR-10 Batch 2:  loss 0.946784
# validation accuracty 0.6026
# Epoch 30, CIFAR-10 Batch 3:  loss 0.831067
# validation accuracty 0.611
# Epoch 30, CIFAR-10 Batch 4:  loss 0.969573
# validation accuracty 0.6008
# Epoch 30, CIFAR-10 Batch 5:  loss 0.913779
# validation accuracty 0.589
# Epoch 31, CIFAR-10 Batch 1:  loss 0.972022
# validation accuracty 0.5948
# Epoch 31, CIFAR-10 Batch 2:  loss 0.911226
# validation accuracty 0.6046
# Epoch 31, CIFAR-10 Batch 3:  loss 0.804531
# validation accuracty 0.617
# Epoch 31, CIFAR-10 Batch 4:  loss 0.946967
# validation accuracty 0.591
# Epoch 31, CIFAR-10 Batch 5:  loss 0.945274
# validation accuracty 0.6014
# Epoch 32, CIFAR-10 Batch 1:  loss 0.999922
# validation accuracty 0.6058
# Epoch 32, CIFAR-10 Batch 2:  loss 0.936664
# validation accuracty 0.6064
# Epoch 32, CIFAR-10 Batch 3:  loss 0.809413
# validation accuracty 0.6082
# Epoch 32, CIFAR-10 Batch 4:  loss 0.926501
# validation accuracty 0.6028
# Epoch 32, CIFAR-10 Batch 5:  loss 0.957843
# validation accuracty 0.5826
# Epoch 33, CIFAR-10 Batch 1:  loss 0.947246
# validation accuracty 0.6102
# Epoch 33, CIFAR-10 Batch 2:  loss 0.950964
# validation accuracty 0.6096
# Epoch 33, CIFAR-10 Batch 3:  loss 0.791789
# validation accuracty 0.611
# Epoch 33, CIFAR-10 Batch 4:  loss 0.951118
# validation accuracty 0.6104
# Epoch 33, CIFAR-10 Batch 5:  loss 0.939943
# validation accuracty 0.6028
# Epoch 34, CIFAR-10 Batch 1:  loss 0.942811
# validation accuracty 0.614
# Epoch 34, CIFAR-10 Batch 2:  loss 0.900084
# validation accuracty 0.604
# Epoch 34, CIFAR-10 Batch 3:  loss 0.784879
# validation accuracty 0.614
# Epoch 34, CIFAR-10 Batch 4:  loss 0.876758
# validation accuracty 0.6108
# Epoch 34, CIFAR-10 Batch 5:  loss 0.939602
# validation accuracty 0.5928
# Epoch 35, CIFAR-10 Batch 1:  loss 1.02283
# validation accuracty 0.614
# Epoch 35, CIFAR-10 Batch 2:  loss 0.931117
# validation accuracty 0.6048
# Epoch 35, CIFAR-10 Batch 3:  loss 0.817498
# validation accuracty 0.6058
# Epoch 35, CIFAR-10 Batch 4:  loss 0.879017
# validation accuracty 0.607
# Epoch 35, CIFAR-10 Batch 5:  loss 0.911116
# validation accuracty 0.5976
# Epoch 36, CIFAR-10 Batch 1:  loss 0.911406
# validation accuracty 0.615
# Epoch 36, CIFAR-10 Batch 2:  loss 0.984203
# validation accuracty 0.6102
# Epoch 36, CIFAR-10 Batch 3:  loss 0.793955
# validation accuracty 0.6018
# Epoch 36, CIFAR-10 Batch 4:  loss 0.912365
# validation accuracty 0.607
# Epoch 36, CIFAR-10 Batch 5:  loss 0.914071
# validation accuracty 0.6104
# Epoch 37, CIFAR-10 Batch 1:  loss 0.94064
# validation accuracty 0.6022
# Epoch 37, CIFAR-10 Batch 2:  loss 0.892038
# validation accuracty 0.6068
# Epoch 37, CIFAR-10 Batch 3:  loss 0.781095
# validation accuracty 0.6134
# Epoch 37, CIFAR-10 Batch 4:  loss 0.804713
# validation accuracty 0.609
# Epoch 37, CIFAR-10 Batch 5:  loss 0.882113
# validation accuracty 0.6092
# Epoch 38, CIFAR-10 Batch 1:  loss 0.972946
# validation accuracty 0.61
# Epoch 38, CIFAR-10 Batch 2:  loss 0.852995
# validation accuracty 0.6132
# Epoch 38, CIFAR-10 Batch 3:  loss 0.789016
# validation accuracty 0.6166
# Epoch 38, CIFAR-10 Batch 4:  loss 0.906699
# validation accuracty 0.6018
# Epoch 38, CIFAR-10 Batch 5:  loss 0.887908
# validation accuracty 0.6048

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.601015127388535

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
