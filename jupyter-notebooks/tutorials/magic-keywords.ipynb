# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,1,300)
for w in range(2,6,3):
    plt.plot(x, np.sin(np.pi*x)*np.sin(2*w*np.pi*x))

# %% [markdown]
# Debugging in the notebook. Turn on the interactive debugger using the using the magig command %pdb

# %%
#turn on interactive debugger using %pdb
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
numbers = [item for item in range(1,5)]
for item in numbers: print(item)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-68c0ec1e9ad1> in <module>()
# ----> 1 numbers = [item for item in range(abcd)]
#       2 for item in numbers: print(item)
#
# NameError: name 'abcd' is not defined
# > <ipython-input-3-68c0ec1e9ad1>(1)<module>()
# ----> 1 numbers = [item for item in range(abcd)]
#       2 for item in numbers: print(item)
#
# ipdb>
